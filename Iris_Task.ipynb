# %%
import pandas as pd
import numpy as np
iris_data = pd.read_csv(r"C:\Users\arcan\OneDrive\My Documents\Data21\iris.csv")

# %%
iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species   rank
# 0             5.1          3.5           1.4          0.2     setosa   17.5
# 1             4.9          3.0           1.4          0.2     setosa   17.5
# 2             4.7          3.2           1.3          0.2     setosa    8.0
# 3             4.6          3.1           1.5          0.2     setosa   30.5
# 4             5.0          3.6           1.4          0.2     setosa   17.5
# ..            ...          ...           ...          ...        ...    ...
# 145           6.7          3.0           5.2          2.3  virginica  117.5
# 146           6.3          2.5           5.0          1.9  virginica  106.5
# 147           6.5          3.0           5.2          2.0  virginica  117.5
# 148           6.2          3.4           5.4          2.3  virginica  121.5
# 149           5.9          3.0           5.1          1.8  virginica  112.5
#
# [150 rows x 6 columns]

# %%
grouped = iris_data.groupby('species').mean()

# %%
grouped
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.418         1.464        0.244
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
iris_data.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
iris_data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
new_iris_df = iris_data.reindex(columns=['sepal_length',
                                         'sepal_width','petal_length',
                                         'petal_width', 'species','rank'])
new_iris_df["rank"] = iris_data["petal_length"].rank()
new_iris_df.sort_values(by="rank")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species   rank
# 22            4.6          3.6           1.0          0.2     setosa    1.0
# 13            4.3          3.0           1.1          0.1     setosa    2.0
# 14            5.8          4.0           1.2          0.2     setosa    3.5
# 35            5.0          3.2           1.2          0.2     setosa    3.5
# 36            5.5          3.5           1.3          0.2     setosa    8.0
# ..            ...          ...           ...          ...        ...    ...
# 131           7.9          3.8           6.4          2.0  virginica  146.0
# 105           7.6          3.0           6.6          2.1  virginica  147.0
# 117           7.7          3.8           6.7          2.2  virginica  148.5
# 122           7.7          2.8           6.7          2.0  virginica  148.5
# 118           7.7          2.6           6.9          2.3  virginica  150.0
#
# [150 rows x 6 columns]

# %%
petal_rank = iris_data.sort_values(by='petal_length')
petal_rank
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 22            4.6          3.6           1.0          0.2     setosa
# 13            4.3          3.0           1.1          0.1     setosa
# 14            5.8          4.0           1.2          0.2     setosa
# 35            5.0          3.2           1.2          0.2     setosa
# 36            5.5          3.5           1.3          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 131           7.9          3.8           6.4          2.0  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 118           7.7          2.6           6.9          2.3  virginica
#
# [150 rows x 5 columns]

# %%
new_grouped = new_iris_df.groupby('species').mean()
new_grouped
# Out:
#             sepal_length  sepal_width  petal_length  petal_width  rank
# species
# setosa             5.006        3.418         1.464        0.244   NaN
# versicolor         5.936        2.770         4.260        1.326   NaN
# virginica          6.588        2.974         5.552        2.026   NaN

# %%
# Out:
#             sepal_length  sepal_width  petal_length  petal_width  rank
# species
# setosa             5.006        3.418         1.464        0.244   NaN
# versicolor         5.936        2.770         4.260        1.326   NaN
# virginica          6.588        2.974         5.552        2.026   NaN

# %%
setosa_df = new_iris_df[new_iris_df['species'] == 'setosa']
setosa_df
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species  rank
# 0            5.1          3.5           1.4          0.2  setosa  17.5
# 1            4.9          3.0           1.4          0.2  setosa  17.5
# 2            4.7          3.2           1.3          0.2  setosa   8.0
# 3            4.6          3.1           1.5          0.2  setosa  30.5
# 4            5.0          3.6           1.4          0.2  setosa  17.5
# 5            5.4          3.9           1.7          0.4  setosa  46.5
# 6            4.6          3.4           1.4          0.3  setosa  17.5
# 7            5.0          3.4           1.5          0.2  setosa  30.5
# 8            4.4          2.9           1.4          0.2  setosa  17.5
# 9            4.9          3.1           1.5          0.1  setosa  30.5
# 10           5.4          3.7           1.5          0.2  setosa  30.5
# 11           4.8          3.4           1.6          0.2  setosa  41.0
# ...

# %%
versicolor_df = iris_data[iris_data['species'] == 'versicolor'].reset_index()
# drop index column drop(columns=index)
versicolor_df = versicolor_df.drop(columns="index")
versicolor_df
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species   rank
# 0            7.0          3.2           4.7          1.4  versicolor   93.0
# 1            6.4          3.2           4.5          1.5  versicolor   83.5
# 2            6.9          3.1           4.9          1.5  versicolor  102.0
# 3            5.5          2.3           4.0          1.3  versicolor   64.0
# 4            6.5          2.8           4.6          1.5  versicolor   89.0
# 5            5.7          2.8           4.5          1.3  versicolor   83.5
# 6            6.3          3.3           4.7          1.6  versicolor   93.0
# 7            4.9          2.4           3.3          1.0  versicolor   52.5
# 8            6.6          2.9           4.6          1.3  versicolor   89.0
# 9            5.2          2.7           3.9          1.4  versicolor   60.0
# 10           5.0          2.0           3.5          1.0  versicolor   54.5
# ...

# %%
virginica_df = iris_data[iris_data['species'] == 'virginica'].reset_index()
# drop index column drop(columns=index)
virginica_df = virginica_df.drop(columns="index")
virginica_df
# Out:
#     sepal_length  sepal_width  petal_length  petal_width    species   rank
# 0            6.3          3.3           6.0          2.5  virginica  140.5
# 1            5.8          2.7           5.1          1.9  virginica  112.5
# 2            7.1          3.0           5.9          2.1  virginica  138.5
# 3            6.3          2.9           5.6          1.8  virginica  128.5
# 4            6.5          3.0           5.8          2.2  virginica  136.0
# 5            7.6          3.0           6.6          2.1  virginica  147.0
# 6            4.9          2.5           4.5          1.7  virginica   83.5
# 7            7.3          2.9           6.3          1.8  virginica  145.0
# 8            6.7          2.5           5.8          1.8  virginica  136.0
# 9            7.2          3.6           6.1          2.5  virginica  143.0
# 10           6.5          3.2           5.1          2.0  virginica  112.5
# ...

# %%
petal_info = iris_data.drop(columns=["sepal_width", "sepal_length"])
petal_info
# Out:
#      petal_length  petal_width    species
# 0             1.4          0.2     setosa
# 1             1.4          0.2     setosa
# 2             1.3          0.2     setosa
# 3             1.5          0.2     setosa
# 4             1.4          0.2     setosa
# ..            ...          ...        ...
# 145           5.2          2.3  virginica
# 146           5.0          1.9  virginica
# 147           5.2          2.0  virginica
# 148           5.4          2.3  virginica
# 149           5.1          1.8  virginica
#
# [150 rows x 3 columns]

# %%
sepal_info = iris_data.drop(columns=["petal_width", "petal_length"])
sepal_info
# Out:
#      sepal_length  sepal_width    species
# 0             5.1          3.5     setosa
# 1             4.9          3.0     setosa
# 2             4.7          3.2     setosa
# 3             4.6          3.1     setosa
# 4             5.0          3.6     setosa
# ..            ...          ...        ...
# 145           6.7          3.0  virginica
# 146           6.3          2.5  virginica
# 147           6.5          3.0  virginica
# 148           6.2          3.4  virginica
# 149           5.9          3.0  virginica
#
# [150 rows x 3 columns]

# %%
# virginica_df, versicolor_df, setosa_df
frames = [virginica_df, versicolor_df, setosa_df]
result = pd.concat(frames)
result
#ignore index set to false
# Out:
#     sepal_length  sepal_width  petal_length  petal_width    species   rank
# 0            6.3          3.3           6.0          2.5  virginica  140.5
# 1            5.8          2.7           5.1          1.9  virginica  112.5
# 2            7.1          3.0           5.9          2.1  virginica  138.5
# 3            6.3          2.9           5.6          1.8  virginica  128.5
# 4            6.5          3.0           5.8          2.2  virginica  136.0
# ..           ...          ...           ...          ...        ...    ...
# 45           4.8          3.0           1.4          0.3     setosa   17.5
# 46           5.1          3.8           1.6          0.2     setosa   41.0
# 47           4.6          3.2           1.4          0.2     setosa   17.5
# 48           5.3          3.7           1.5          0.2     setosa   30.5
# 49           5.0          3.3           1.4          0.2     setosa   17.5
#
# [150 rows x 6 columns]

# %%
# petal_info, sepal_info
merge_species = pd.merge(sepal_info, petal_info, left_index=True, right_index=True)
merge_species
# Then drop columns that appear multiple times.
# Out:
#      sepal_length  sepal_width  species_x  petal_length  petal_width  \
# 0             5.1          3.5     setosa           1.4          0.2
# 1             4.9          3.0     setosa           1.4          0.2
# 2             4.7          3.2     setosa           1.3          0.2
# 3             4.6          3.1     setosa           1.5          0.2
# 4             5.0          3.6     setosa           1.4          0.2
# ..            ...          ...        ...           ...          ...
# 145           6.7          3.0  virginica           5.2          2.3
# 146           6.3          2.5  virginica           5.0          1.9
# 147           6.5          3.0  virginica           5.2          2.0
# 148           6.2          3.4  virginica           5.4          2.3
# 149           5.9          3.0  virginica           5.1          1.8
#
#      species_y
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# ...
